# %% [markdown]
# <h1> Bank Data Analysis </h1>

# %% [markdown]
# <h2> 1) Libraries </h2>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd
import scipy as sp 
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    fbeta_score,
    make_scorer,
    recall_score,
)
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.tree import DecisionTreeClassifier

plt.style.use("tableau-colorblind10")

# %% [markdown]
# <h2> 2) Data Importation </h2>

# %%
data = pd.read_csv('/Users/arnaudcruchaudet/Desktop/Big Data/bank_data.csv', header=0)
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# Here my conclusion for bank strategies and customers segmentation: <br>
# <ul>
#     <li>Deposit: Attract new customers</li>
#     <li>Loan: To increase the actual customers consumption</li>
#     <li>Housing: A combination of the 2 variables above</li>
# </ul>

# %% [markdown]
# <h2> 3) Splitting Data </h2>

# %%
X = data.iloc[:, :16]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h2> 4) Checking Data Type </h2>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# Observations: <br>
# <ul>
#     <li> 11162 rows </li>
#     <li> 17 variables </li>
#     <li> 7 as int64 </li>
#     <li> 10 as object </li>
# <ul>

# %% [markdown]
# We will have to convert the variables objects data type to category data type

# %%
data.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# max      854.000000     58.000000

# %% [markdown]
# <h3> 4.1) Convert object data type to category </h3>

# %%
set_as_category = [
    'job',
    'marital',
    'education',
    'default',
    'housing',
    'loan',
    'contact',
    'month',
    'poutcome',
]

data[set_as_category] = data[set_as_category].astype('category')

# %% [markdown]
# <h3> 4.2) Recode the target variable (no=0, yes=1) </h3>

# %%
data['deposit'] = np.where(data['deposit'] == 'no', 0, 1)

# %% [markdown]
# <h2> 5) Visualization </h2>

# %% [markdown]
# <h3> 5.1) Categorical features proportions Function </h3>

# %%
def counts_plot(y, col='w', ax=None):

    y_counts = (
        data.loc[:, y]
        .value_counts()
        .reset_index()
        .rename(columns={'index':y, y: 'counts'})
        .assign(
            percent=lambda df_: (df_["counts"]/ df_["counts"].sum()).round(2) * 100
        )
    )

    sns.set_context("paper")
    ax0 = sns.barplot(
        data = y_counts,
        x = 'percent',
        y = y,
        color = col,
        ax = ax,
        order = y_counts[y],
    )

    values1 = ax0.containers[0].datavalues
    labels = ["{:g}%".format(val) for val in values1]
    ax0.bar_label(ax0.containers[0], labels=labels, fontsize=9, color="#740405")
    ax0.set_ylabel("")
    ax0.set_xlabel("Percent", fontsize=10)
    ax0.set_title(str.title(y) + " | proportions ", fontsize=10)
    return

# %% [markdown]
# <h4> 5.1.1) Job, Housing, Marital, and Education Distributions

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize= (12, 6))
counts_plot('job', ax=ax1, col='bisque')
counts_plot('housing', ax=ax2, col= 'cornflowerblue')
counts_plot('marital', ax=ax3, col='indianred')
counts_plot('education', ax=ax4, col='hotpink')
fig.tight_layout()
plt.show()

# %% [markdown]
# <h4> 5.1.2) Default, Loan, Contact and Poutcome Distributions </h4>

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize= (12, 6))
counts_plot('default', ax=ax1, col='bisque')
counts_plot('loan', ax=ax2, col= 'cornflowerblue')
counts_plot('contact', ax=ax3, col='indianred')
counts_plot('poutcome', ax=ax4, col='hotpink')
fig.tight_layout()
plt.show()

# %% [markdown]
# <h3> 5.1.3) Contact Features </h3>

# %%
sns.set(rc = {'figure.figsize':(6, 5)})
contact = sns.countplot(x="contact", data = data, hue = "deposit", order = data["contact"].value_counts().index)
contact.tick_params(axis='x', rotation=60)
plt.title("Bivariate analysis of the relationship between 'contact' and 'deposit'")
plt.show()

# %% [markdown]
# The direct ratio in this graph shows that people who were contacted by cellular got subscribed more to a deposit term.

# %% [markdown]
# <h3> 5.2) Target Variable </h3>

# %% [markdown]
# <h4> 5.2.1) Target Variable Counts </h4>

# %%
y = (
    data["deposit"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "deposit", "deposit": "counts"})
    .assign(percent=lambda df_: (df_["counts"] / df_["counts"].sum()).round(2) * 100)
)

print(y)
# Out:
#    deposit  counts  percent
# 0        0    5873     53.0
# 1        1    5289     47.0

# %% [markdown]
# <h4> 5.2.2) Target Variable Proportion (PIE CHART) </h4>

# %%
target_color = sns.color_palette(['tan', 'royalblue'])

plt.pie(
    x = (y['counts'] / y['counts'].sum()) * 100,
    labels = ["0 | Not subscribed", "1 | subscribed"],
    colors=target_color,
    autopct="%.0f%%",
    shadow=True, 
    textprops = {"fontsize": 10, "color": "#000000"},
    explode=[0.1, 0],
)

plt.title("Target Variable proportions", fontsize=14)
plt.show()

# %% [markdown]
# <h3> 5.3) Numerical features analysis </h3>

# %% [markdown]
# <h4> 5.3.1) Numerical features (pairplot) </h4>

# %%
numeric_features = data.select_dtypes("integer").copy()

sample_for_pairplot = numeric_features.groupby("deposit", group_keys=False).apply(
    lambda x: x.sample(frac=0.01)
)

sns.pairplot(
    sample_for_pairplot,
    hue = 'deposit',
    kind= "scatter",
    diag_kind='kde',
    palette=target_color,
    height=1.5,
    aspect= 1,
    plot_kws=dict(s=10)
)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h4> 5.3.2) Age, Duration, Balance, and Campaign Variable </h4>

# %% [markdown]
# <h5> 5.3.2.1) Function </h5>

# %%
def num_distributions(var_1, var_2):

    age_dur = data[[var_1, var_2, "deposit"]]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

    ## HistPlot

    sns.histplot(
        data=age_dur,
        kde=True,
        line_kws={"lw": 1.5, "alpha": 0.6},
        x=var_1,
        bins=20,
        hue="deposit",
        palette=target_color,
        alpha=0.6,
        ax=ax1,
    )
    ax1.legend(
        title="Subscribed?",
        loc="upper right",
        labels=["YES", "NO"],
        ncol=2,
        frameon=True,
        shadow=True,
        title_fontsize=8,
        prop={"size": 7},
        bbox_to_anchor=(1.18, 1.25),
    )
    ax1.set_xlabel(str.title(var_1), fontsize=10)
    ax1.set_ylabel("Frequency", fontsize=10)
    ax1.set_title(str.title(var_1) + " distributions", fontsize=12)
    ax1.yaxis.set_major_formatter(ticker.EngFormatter())

    ## Scatter plot

    sns.scatterplot(
        data=age_dur,
        x=var_1,
        y=var_2,
        hue="deposit",
        ax=ax2,
        palette=target_color,
        legend=False,
        alpha=0.6,
    )
    ax2.yaxis.set_major_formatter(ticker.EngFormatter())
    ax2.set_title(str.title(var_2) + " distributions", fontsize=12)
    ax2.set_ylabel(str.title(var_2), fontsize=10)
    ax2.set_xlabel(str.title(var_1), fontsize=10)

    return

# %% [markdown]
# <h5> 5.3.2.2) Age and Duration </h5>

# %%
num_distributions("age", "duration")

# %% [markdown]
# <h5> 5.3.2.3) Age and Balance </h5>

# %%
num_distributions("age", "balance")

# %% [markdown]
# <h5> 5.3.2.4) Balance and Duration </h5>

# %%
num_distributions("age", "duration")

# %% [markdown]
# <h5> 5.3.2.5) Balance and Campaign </h5>

# %%
num_distributions("balance", "campaign")

# %% [markdown]
# Who talks more ?

# %%
larg_dur = data["duration"].nlargest(10)
small_dur = data["duration"].nsmallest(5)
data.query("duration in @larg_dur | duration in @small_dur").sort_values(
    by="duration", ascending=False
).style.background_gradient()
# Out:
# <style type="text/css">
# #T_50e0e_row0_col0, #T_50e0e_row0_col11, #T_50e0e_row0_col16, #T_50e0e_row2_col16, #T_50e0e_row3_col16, #T_50e0e_row4_col16, #T_50e0e_row5_col16, #T_50e0e_row6_col16, #T_50e0e_row7_col16, #T_50e0e_row8_col16, #T_50e0e_row9_col12, #T_50e0e_row9_col16, #T_50e0e_row10_col14, #T_50e0e_row11_col5, #T_50e0e_row11_col9, #T_50e0e_row12_col14, #T_50e0e_row13_col13, #T_50e0e_row14_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_50e0e_row0_col5, #T_50e0e_row1_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_50e0e_row0_col9 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_50e0e_row0_col12, #T_50e0e_row4_col12, #T_50e0e_row10_col12, #T_50e0e_row11_col12, #T_50e0e_row12_col9, #T_50e0e_row13_col14 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_50e0e_row0_col13, #T_50e0e_row0_col14, #T_50e0e_row1_col12, #T_50e0e_row1_col13, #T_50e0e_row1_col14, #T_50e0e_row1_col16, #T_50e0e_row2_col5, #T_50e0e_row2_col12, #T_50e0e_row2_col13, #T_50e0e_row2_col14, #T_50e0e_row3_col13, #T_50e0e_row3_col14, #T_50e0e_row4_col13, #T_50e0e_row4_col14, #T_50e0e_row5_col13, #T_50e0e_row5_col14, #T_50e0e_row6_col12, #T_50e0e_row6_col13, #T_50e0e_row6_col14, #T_50e0e_row7_col9, #T_50e0e_row7_col13, #T_50e0e_row7_col14, #T_50e0e_row8_col12, #T_50e0e_row8_col13, #T_50e0e_row8_col14, #T_50e0e_row9_col13, #T_50e0e_row9_col14, #T_50e0e_row10_col11, #T_50e0e_row10_col16, #T_50e0e_row11_col11, #T_50e0e_row11_col13, #T_50e0e_row11_col14, #T_50e0e_row11_col16, #T_50e0e_row12_col11, #T_50e0e_row12_col12, #T_50e0e_row12_col16, #T_50e0e_row13_col11, #T_50e0e_row13_col12, #T_50e0e_row13_col16, #T_50e0e_row14_col11, #T_50e0e_row14_col12, #T_50e0e_row14_col16, #T_50e0e_row15_col0, #T_50e0e_row15_col11, #T_50e0e_row15_col12, #T_50e0e_row15_col13, #T_50e0e_row15_col14, #T_50e0e_row15_col16, #T_50e0e_row16_col11, #T_50e0e_row16_col12, #T_50e0e_row16_col13, #T_50e0e_row16_col14, #T_50e0e_row16_col16, #T_50e0e_row17_col11, #T_50e0e_row17_col12, #T_50e0e_row17_col13, #T_50e0e_row17_col14, #T_50e0e_row17_col16 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_50e0e_row1_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_50e0e_row1_col9, #T_50e0e_row5_col9 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_50e0e_row1_col11 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_50e0e_row2_col0, #T_50e0e_row9_col0, #T_50e0e_row13_col0, #T_50e0e_row17_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_50e0e_row2_col9 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_50e0e_row2_col11 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_50e0e_row3_col0, #T_50e0e_row6_col5, #T_50e0e_row7_col5 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_50e0e_row3_col5, #T_50e0e_row16_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_50e0e_row3_col9, #T_50e0e_row4_col0, #T_50e0e_row10_col5 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_50e0e_row3_col11 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_50e0e_row3_col12, #T_50e0e_row5_col12, #T_50e0e_row6_col9, #T_50e0e_row7_col12, #T_50e0e_row14_col14 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_50e0e_row4_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_50e0e_row4_col9 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_50e0e_row4_col11, #T_50e0e_row5_col11 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_50e0e_row5_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_50e0e_row5_col5, #T_50e0e_row12_col5, #T_50e0e_row15_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_50e0e_row6_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_50e0e_row6_col11 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_50e0e_row7_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_50e0e_row7_col11 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_50e0e_row8_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_50e0e_row8_col5 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_50e0e_row8_col9 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_50e0e_row8_col11, #T_50e0e_row9_col11 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_50e0e_row9_col5, #T_50e0e_row16_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_50e0e_row9_col9 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_50e0e_row10_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_50e0e_row10_col9 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_50e0e_row10_col13 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_50e0e_row11_col0 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_50e0e_row12_col0, #T_50e0e_row13_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_50e0e_row12_col13 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_50e0e_row13_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_50e0e_row14_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_50e0e_row14_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_50e0e_row14_col9 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_50e0e_row15_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_50e0e_row16_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_50e0e_row17_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_50e0e_row17_col9 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50e0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50e0e_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_50e0e_level0_col1" class="col_heading level0 col1" >job</th>
#       <th id="T_50e0e_level0_col2" class="col_heading level0 col2" >marital</th>
#       <th id="T_50e0e_level0_col3" class="col_heading level0 col3" >education</th>
#       <th id="T_50e0e_level0_col4" class="col_heading level0 col4" >default</th>
#       <th id="T_50e0e_level0_col5" class="col_heading level0 col5" >balance</th>
#       <th id="T_50e0e_level0_col6" class="col_heading level0 col6" >housing</th>
#       <th id="T_50e0e_level0_col7" class="col_heading level0 col7" >loan</th>
#       <th id="T_50e0e_level0_col8" class="col_heading level0 col8" >contact</th>
#       <th id="T_50e0e_level0_col9" class="col_heading level0 col9" >day</th>
#       <th id="T_50e0e_level0_col10" class="col_heading level0 col10" >month</th>
#       <th id="T_50e0e_level0_col11" class="col_heading level0 col11" >duration</th>
#       <th id="T_50e0e_level0_col12" class="col_heading level0 col12" >campaign</th>
#       <th id="T_50e0e_level0_col13" class="col_heading level0 col13" >pdays</th>
#       <th id="T_50e0e_level0_col14" class="col_heading level0 col14" >previous</th>
#       <th id="T_50e0e_level0_col15" class="col_heading level0 col15" >poutcome</th>
#       <th id="T_50e0e_level0_col16" class="col_heading level0 col16" >deposit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50e0e_level0_row0" class="row_heading level0 row0" >271</th>
#       <td id="T_50e0e_row0_col0" class="data row0 col0" >59</td>
#       <td id="T_50e0e_row0_col1" class="data row0 col1" >management</td>
#       <td id="T_50e0e_row0_col2" class="data row0 col2" >married</td>
#       <td id="T_50e0e_row0_col3" class="data row0 col3" >secondary</td>
#       <td id="T_50e0e_row0_col4" class="data row0 col4" >no</td>
#       <td id="T_50e0e_row0_col5" class="data row0 col5" >1321</td>
#       <td id="T_50e0e_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_50e0e_row0_col7" class="data row0 col7" >no</td>
#       <td id="T_50e0e_row0_col8" class="data row0 col8" >unknown</td>
#       <td id="T_50e0e_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_50e0e_row0_col10" class="data row0 col10" >jun</td>
#       <td id="T_50e0e_row0_col11" class="data row0 col11" >3881</td>
#       <td id="T_50e0e_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_50e0e_row0_col13" class="data row0 col13" >-1</td>
#       <td id="T_50e0e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_50e0e_row0_col15" class="data row0 col15" >unknown</td>
#       <td id="T_50e0

# %% [markdown]
# <h5> 5.3.2.6) Default and target Variable "y" </h5>

# %%
y = (
    data[["default", "deposit"]]
    .value_counts()
    .reset_index()
    .rename(columns={0: "counts"})
)

print(y)
# Out:
#   default  deposit  counts
# 0      no        0    5757
# 1      no        1    5237
# 2     yes        0     116
# 3     yes        1      52

# %%
default_and_target = (
    data[["default", "deposit"]]
    .value_counts()
    .reset_index()
    .rename(columns={0: "counts"})
)

fig, ax = plt.subplots(1, 1)

sns.barplot(
    data=default_and_target,
    x="default",
    y="counts",
    hue="deposit",
    palette=target_color,
    alpha=0.8,
)
ax.set_title("Default distributions vs Target (y)", fontsize=12)
ax.set_ylabel("Counts")
ax.set_xlabel("Default", fontsize=10)
ax.yaxis.set_major_formatter(ticker.EngFormatter())
ax.legend(
    title="Subscribed?",
    loc="upper right",
    ncol=2,
    frameon=True,
    shadow=True,
    title_fontsize=8,
    prop={"size": 9},
)
plt.show()

# %% [markdown]
# <h5> 5.3.2.7) Default, Balance and target Variable "y" </h5>

# %%
y = (
    data[["balance", "default", "deposit"]]
    .groupby(["default", "deposit"])["balance"]
    .agg(["mean", "count"])
    .reset_index()
)

print(y)
# Out:
#   default  deposit         mean  count
# 0      no        0  1307.270974   5757
# 1      no        1  1822.793775   5237
# 2     yes        0   -61.939655    116
# 3     yes        1   -61.500000     52

# %% [markdown]
# <h2> 6) Model </h2>

# %%
X = data.iloc[:, :16]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# <h3> 6.1) Encoding </h3>

# %%
binary_columns = list(X_train.select_dtypes(include="category").columns.values)
binary_columns
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
# I remove educational variable be cause he was encoded as an ordinal type
binary_columns.remove("education")
binary_columns
# Out:
# ['job',
#  'marital',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
X_train = pd.get_dummies(
    X_train, prefix=binary_columns, columns=binary_columns, drop_first=True
)
X_train.head()
# Out:
#       age  education  balance  day  duration  campaign  pdays  previous  \
# 2265   55  secondary     1662    4        94         2     -1         0
# 1525   39   tertiary    -3058   17       882         3     -1         0
# 1837   51  secondary     3025    7       476         1    352         1
# 9423   38    primary      -87   13       531         1     -1         0
# 8111   36  secondary      205   18       176         4     -1         0
#
#       job_blue-collar  job_entrepreneur  ...  month_jul  month_jun  month_mar  \
# 2265                0                 0  ...          0          1          0
# 1525                0                 0  ...          0          0          0
# 1837                0                 0  ...          0          0          0
# 9423                0                 0  ...          0          0          0
# 8111                0                 0  ...          0          0          0
#
#       month_may  month_nov  month_oct  month_sep  poutcome_other  \
# 2265          0          0          0          0               0
# 1525          0          0          0          0               0
# 1837          1          0          0          0               1
# 9423          1          0          0          0               0
# 8111          0          1          0          0               0
#
#       poutcome_success  poutcome_unknown
# 2265                 0                 1
# 1525                 0                 1
# 1837                 0                 0
# 9423                 0                 1
# 8111                 0                 1
#
# [5 rows x 40 columns]

# %%
recode_education_var = {"unknown": 0, "primary": 1, "secondary": 2, "tertiary": 3}
X_train["education"] = X_train["education"].replace(recode_education_var)
X_train["education"].value_counts(normalize=True)
# Out:
# 2    0.491617
# 3    0.330347
# 1    0.132983
# 0    0.045053
# Name: education, dtype: float64

# %%
X_test = pd.get_dummies(
    X_test, prefix=binary_columns, columns=binary_columns, drop_first=True
)
X_test.head()
# Out:
#       age  education  balance  day  duration  campaign  pdays  previous  \
# 9058   41    unknown       88   11       105         1    336         2
# 3279   56  secondary     1938   26       229         1    192         4
# 6502   30  secondary      245    8       187         2     -1         0
# 9327   34   tertiary     1396   17       630         1     -1         0
# 9965   29  secondary      -13   14       512         3     -1         0
#
#       job_blue-collar  job_entrepreneur  ...  month_jul  month_jun  month_mar  \
# 9058                0                 0  ...          0          0          0
# 3279                0                 0  ...          0          0          0
# 6502                0                 0  ...          1          0          0
# 9327                0                 0  ...          1          0          0
# 9965                0                 0  ...          0          0          0
#
#       month_may  month_nov  month_oct  month_sep  poutcome_other  \
# 9058          1          0          0          0               0
# 3279          0          0          0          0               0
# 6502          0          0          0          0               0
# 9327          0          0          0          0               0
# 9965          1          0          0          0               0
#
#       poutcome_success  poutcome_unknown
# 9058                 0                 0
# 3279                 1                 0
# 6502                 0                 1
# 9327                 0                 1
# 9965                 0                 1
#
# [5 rows x 40 columns]

# %%
X_test["education"] = X_test["education"].replace(recode_education_var)

# %% [markdown]
# <h3> 6.2) Random Forest Model </h3>

# %%
rf = RandomForestClassifier(
    n_jobs=-1, random_state=0, class_weight="balanced_subsample"
)

# %%
rs = make_scorer(recall_score)

# %%
cv = cross_val_score(rf, X_train, y_train, cv=10, n_jobs=-1, scoring=rs)
print("Cross validation scores: {}".format(cv))
print("%0.2f recall with a standard deviation of %0.2f" % (cv.mean(), cv.std()))
# Out:
# Cross validation scores: [0.85294118 0.87700535 0.87131367 0.8847185  0.88739946 0.90616622
#  0.87131367 0.8847185  0.89276139 0.86595174]
# 0.88 recall with a standard deviation of 0.01

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', n_jobs=-1,
#                        random_state=0)

# %%
pred = rf.predict(X_train)
print("The train recall score is {}".format(np.round(recall_score(y_train, pred), 4)))
# Out:
# The train recall score is 1.0

# %%
sns.heatmap(
    confusion_matrix(y_train, pred),
    annot=True,
    fmt="g",
    cbar=False,
    cmap="Reds",
    annot_kws={"size": 15},
)
plt.title("Confusion matrix (Train set)", fontsize=16)
plt.yticks(rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
print(classification_report(y_train, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4081
#            1       1.00      1.00      1.00      3732
#
#     accuracy                           1.00      7813
#    macro avg       1.00      1.00      1.00      7813
# weighted avg       1.00      1.00      1.00      7813

# %%
pred = rf.predict(X_test)
print("The test recall score is {}".format(np.round(recall_score(y_test, pred), 4)))
# Out:
# The test recall score is 0.8805

# %%
sns.heatmap(
    confusion_matrix(y_test, pred),
    annot=True,
    fmt="g",
    cmap="Reds",
    cbar=False,
    annot_kws={"size": 15},
)
plt.title("Confusion matrix (Test set)", fontsize=16)
plt.yticks(rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1792
#            1       0.82      0.88      0.85      1557
#
#     accuracy                           0.86      3349
#    macro avg       0.86      0.86      0.86      3349
# weighted avg       0.86      0.86      0.86      3349

# %% [markdown]
# <h3> 6.3) Logistic Regression </h3>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, make_scorer, accuracy_score

# Define the pipeline steps
pipeline_steps = [
    ('scaler', StandardScaler()),  # Step 1: Default to StandardScaler, can be changed in GridSearchCV
    ('logreg', LogisticRegression())  # Step 2: Logistic Regression
]

# Create the pipeline
pipeline = Pipeline(pipeline_steps)

# Define the hyperparameters and their ranges
param_grid = {
    'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'logreg__C': [0.001, 0.01, 0.1, 1, 10],
    'logreg__penalty': ['l1', 'l2']
}

# Define the scorer
scorer = make_scorer(accuracy_score)

# Create the GridSearchCV object
grid_search = GridSearchCV(pipeline, param_grid=param_grid, scoring=scorer, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Get the best estimator
best_estimator = grid_search.best_estimator_

# Predict on the test set
y_pred = best_estimator.predict(X_test)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# /Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 75 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/arnaudcruchaudet/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.78262026 0.6555056  0.76750048
#         nan        nan        nan 0.79460265 0.69638426 0.79516187
#         nan        nan        nan 0.79639449 0.76481316 0.79740239
#         nan        nan        nan 0.79796255 0.79202719 0.79729054
#         nan        nan        nan 0.79807454 0.79628238 0.79785057]
#   warnings.warn(
# Best parameters: {'logreg__C': 10, 'logreg__penalty': 'l2', 'scaler': StandardScaler()}
# Best score: 0.7980745355252964
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      1205
#            1       0.80      0.76      0.78      1028
#
#     accuracy                           0.80      2233
#    macro avg       0.80      0.80      0.80      2233
# weighted avg       0.80      0.80      0.80      2233

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(confusion_matrix(y_pred, y_test), annot=True, fmt="g", cmap="magma")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Something to think: <br>
# <ul>
#     <li> We can fill unknown job values with mode value but also we can fill unknown job values with mode of education degree per job. </li>
#     <li> We can fill unknown values at education column </li>
#     <li> We can fill unknown values at contact with mode </li>
#     <li> Maybe we can remove the column "ID", "day", and "month </li>
# <ul>

# %% [markdown]
# <h2> 7) Handle Unknown Values </h2>

# %%
data['job'].value_counts()
# Out:
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: job, dtype: int64

# %% [markdown]
# Has we saw previously, it's look like dataset has no "NaN" values but dataset has "unknown" values. <br>
#
# We can fill unknown job values with mode value but also we can fill unknown job values with mode of education degree per job.

# %% [markdown]
# <h3> 7.1) eduRatio => Handle Job Unknow Values

# %% [markdown]
# <h4> Step 1: Calculate the Most Common Education Level and Its Percentage for Each Job Type </h4>

# %%
# Step 1: Find the most common education level for each job type
eduRatio = pd.DataFrame()
for job_type in data["job"].unique():
    job_data = data[data["job"] == job_type]["education"]
    most_common_education = job_data.mode()[0]  # Find the most common education level
    most_common_pct = job_data.value_counts(normalize=True).iloc[0] * 100  # Find the percentage of the most common education level
    new_row = pd.DataFrame({'Job': [job_type], 'MostCommonEducation': [most_common_education], 'MostCommonEducationPct': [most_common_pct]})
    eduRatio = pd.concat([eduRatio, new_row], ignore_index=True)
eduRatio
# Out:
#               Job MostCommonEducation  MostCommonEducationPct
# 0          admin.           secondary               81.259370
# 1      technician           secondary               66.319254
# 2        services           secondary               80.823402
# 3      management            tertiary               84.879189
# 4         retired           secondary               40.359897
# 5     blue-collar           secondary               57.407407
# 6      unemployed           secondary               58.823529
# 7    entrepreneur           secondary               42.987805
# 8       housemaid             primary               52.554745
# 9         unknown             unknown               55.714286
# 10  self-employed            tertiary               56.790123
# 11        student           secondary               52.500000

# %% [markdown]
# <h4> Step 2: Impute 'Unknown' Job Types Based on the Most Common Education Level </h4>

# %%
# Step 2: Use this information to impute 'unknown' job types
for edu_level in data[data['job'] == 'unknown']['education'].unique():
    # Find the job type whose most common education level matches 'edu_level'
    matching_job = eduRatio[eduRatio['MostCommonEducation'] == edu_level]['Job'].iloc[0]
    # Fill in 'unknown' job types with the 'matching_job' for rows where education level is 'edu_level'
    data.loc[(data['job'] == 'unknown') & (data['education'] == edu_level), 'job'] = matching_job

data['job'].value_counts()
# Out:
# management       2575
# blue-collar      1944
# technician       1823
# admin.           1349
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         281
# unknown            39
# Name: job, dtype: int64

# %% [markdown]
# <h4> Step 3: For Any Remaining 'Unknown' Job Values, Use a Weighted Random Choice Based on MostCommonEducationPct </h4>

# %%
import random

# Step 3: For any remaining 'unknown' job values, use a weighted random choice based on MostCommonEducationPct
# Normalize the percentages to sum to 1 (probabilities)
eduRatio['NormalizedPct'] = eduRatio['MostCommonEducationPct'] / eduRatio['MostCommonEducationPct'].sum()
job_weights = eduRatio.set_index('Job')['NormalizedPct'].to_dict()

# For each 'unknown' job, assign a job type based on the weighted distribution
for idx in data[data['job'] == 'unknown'].index:
    data.at[idx, 'job'] = random.choices(list(job_weights.keys()), weights=job_weights.values(), k=1)[0]

data['job'].value_counts()
# Out:
# management       2581
# blue-collar      1946
# technician       1825
# admin.           1352
# services          926
# retired           781
# self-employed     411
# student           364
# unemployed        360
# entrepreneur      330
# housemaid         284
# unknown             2
# Name: job, dtype: int64

# %% [markdown]
# <h4> Step 4: Assign a Default Job Type to Any Remaining 'Unknown' Job Entries </h4>

# %%
# Define a default job type
default_job_type = 'blue-collar'  # or any other job type based on your analysis or domain knowledge

# Assign the default job type to any remaining 'unknown' job entries
data.loc[data['job'] == 'unknown', 'job'] = default_job_type

# Verify that there are no more 'unknown' job values
print(data['job'].value_counts())
# Out:
# management       2581
# blue-collar      1948
# technician       1825
# admin.           1352
# services          926
# retired           781
# self-employed     411
# student           364
# unemployed        360
# entrepreneur      330
# housemaid         284
# unknown             0
# Name: job, dtype: int64

# %% [markdown]
# <h3> 7.2) eduRatio => Handle Education Unknown Values </h3>

# %%
data["education"].value_counts()
# Out:
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# Name: education, dtype: int64

# %%
job_education_mapping = {
    "admin.": "secondary",
    "management": "secondary",
    "services": "tertiary",
    "technician": "secondary",
    "retired": "secondary",
    "blue-collar": "secondary",
    "housemaid": "primary",
    "self-employed": "tertiary",
    "student": "secondary",
    "entrepreneur": "tertiary",
    "unemployed": "secondary",
    # Add more mappings if needed
}

for job_type, education_level in job_education_mapping.items():
    condition = (data.education == "unknown") & (data.job == job_type)
    data.loc[condition, "education"] = education_level

# For any remaining 'unknown' education values, set them to 'secondary'
data.loc[data.education == "unknown", "education"] = "secondary"

# Verify that there are no more 'unknown' education values
print(data['education'].value_counts())
# Out:
# secondary    5884
# tertiary     3766
# primary      1512
# unknown         0
# Name: education, dtype: int64

# %% [markdown]
# <h3> 7.3) Contact Unknown Values </h3>

# %%
data['contact'].value_counts()
# Out:
# cellular     8042
# unknown      2346
# telephone     774
# Name: contact, dtype: int64

# %%
data["contact"].replace(["unknown"],data["contact"].mode(),inplace = True) # I replace unknown contact values with mode value
data['contact'].value_counts()
# Out:
# cellular     10388
# telephone      774
# Name: contact, dtype: int64

# %% [markdown]
# <h3> 7.4) No need Day, and Month columns

# %%
data.drop(columns = ["day","month"],inplace = True)

# %% [markdown]
# <h2> 8) Redo basic </h2>

# %%
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   59      admin.  married  secondary      no     2343     yes   no
# 1   56      admin.  married  secondary      no       45      no   no
# 2   41  technician  married  secondary      no     1270     yes   no
# 3   55    services  married  secondary      no     2476     yes   no
# 4   54      admin.  married   tertiary      no      184      no   no
#
#     contact  duration  campaign  pdays  previous poutcome  deposit
# 0  cellular      1042         1     -1         0  unknown        1
# 1  cellular      1467         1     -1         0  unknown        1
# 2  cellular      1389         1     -1         0  unknown        1
# 3  cellular       579         1     -1         0  unknown        1
# 4  cellular       673         2     -1         0  unknown        1

# %% [markdown]
# <h3> 8.1) Splitting Data </h3>

# %%
X = data.iloc[:, :14]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h3> 8.2) Encoding </h3>

# %%
binary_columns = list(X_train.select_dtypes(include="category").columns.values)
binary_columns
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'poutcome']

# %%
# I remove educational variable be cause he was encoded as an ordinal type
binary_columns.remove("education")
binary_columns
# Out:
# ['job', 'marital', 'default', 'housing', 'loan', 'contact', 'poutcome']

# %%
X_train = pd.get_dummies(
    X_train, prefix=binary_columns, columns=binary_columns, drop_first=True
)
X_train.head()
# Out:
#       age  education  balance  duration  campaign  pdays  previous  \
# 6111   49  secondary      104       285         1     -1         0
# 1149   59  secondary      514       261         1     -1         0
# 2954   33    primary      195       984         5     -1         0
# 2458   58  secondary      687       221         1     99         2
# 7504   33  secondary     1077       432         3    374         3
#
#       job_blue-collar  job_entrepreneur  job_housemaid  ...  job_unknown  \
# 6111                0                 0              0  ...            0
# 1149                0                 0              0  ...            0
# 2954                1                 0              0  ...            0
# 2458                0                 0              0  ...            0
# 7504                0                 0              0  ...            0
#
#       marital_married  marital_single  default_yes  housing_yes  loan_yes  \
# 6111                1               0            0            1         0
# 1149                0               0            0            0         0
# 2954                1               0            0            0         0
# 2458                1               0            0            1         0
# 7504                1               0            0            1         0
#
#       contact_telephone  poutcome_other  poutcome_success  poutcome_unknown
# 6111                  0               0                 0                 1
# 1149                  0               0                 0                 1
# 2954                  0               0                 0                 1
# 2458                  0               0                 1                 0
# 7504                  0               1                 0                 0
#
# [5 rows x 27 columns]

# %%
recode_education_var = {"unknown": 0, "primary": 1, "secondary": 2, "tertiary": 3}
X_train["education"] = X_train["education"].replace(recode_education_var)
X_train["education"].value_counts(normalize=True)
# Out:
# 2    0.528839
# 3    0.335872
# 1    0.135290
# 0    0.000000
# Name: education, dtype: float64

# %%
X_test = pd.get_dummies(
    X_test, prefix=binary_columns, columns=binary_columns, drop_first=True
)
X_test.head()
# Out:
#       age  education  balance  duration  campaign  pdays  previous  \
# 9058   41   tertiary       88       105         1    336         2
# 3279   56  secondary     1938       229         1    192         4
# 6502   30  secondary      245       187         2     -1         0
# 9327   34   tertiary     1396       630         1     -1         0
# 9965   29  secondary      -13       512         3     -1         0
#
#       job_blue-collar  job_entrepreneur  job_housemaid  ...  job_unknown  \
# 9058                0                 0              0  ...            0
# 3279                0                 0              0  ...            0
# 6502                0                 0              0  ...            0
# 9327                0                 0              0  ...            0
# 9965                0                 0              0  ...            0
#
#       marital_married  marital_single  default_yes  housing_yes  loan_yes  \
# 9058                1               0            0            1         0
# 3279                1               0            0            0         1
# 6502                0               1            0            0         1
# 9327                0               1            0            1         0
# 9965                0               1            0            1         0
#
#       contact_telephone  poutcome_other  poutcome_success  poutcome_unknown
# 9058                  0               0                 0                 0
# 3279                  0               0                 1                 0
# 6502                  0               0                 0                 1
# 9327                  0               0                 0                 1
# 9965                  0               0                 0                 1
#
# [5 rows x 27 columns]

# %%
X_test["education"] = X_test["education"].replace(recode_education_var)

# %% [markdown]
# <h3> 8.3) Random Forest </h3>

# %%
rf = RandomForestClassifier(
    n_jobs=-1, random_state=0, class_weight="balanced_subsample"
)

# %%
rs = make_scorer(recall_score)

# %%
cv = cross_val_score(rf, X_train, y_train, cv=10, n_jobs=-1, scoring=rs)
print("Cross validation scores: {}".format(cv))
print("%0.2f recall with a standard deviation of %0.2f" % (cv.mean(), cv.std()))
# Out:
# Cross validation scores: [0.81924883 0.82159624 0.8028169  0.84037559 0.82159624 0.80046948
#  0.84741784 0.80985915 0.83606557 0.83098592]
# 0.82 recall with a standard deviation of 0.01

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', n_jobs=-1,
#                        random_state=0)

# %%
pred = rf.predict(X_train)
print("The train recall score is {}".format(np.round(recall_score(y_train, pred), 4)))
# Out:
# The train recall score is 1.0

# %%
sns.heatmap(
    confusion_matrix(y_train, pred),
    annot=True,
    fmt="g",
    cbar=False,
    cmap="Reds",
    annot_kws={"size": 15},
)
plt.title("Confusion matrix (Train set)", fontsize=16)
plt.yticks(rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
print(classification_report(y_train, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4668
#            1       1.00      1.00      1.00      4261
#
#     accuracy                           1.00      8929
#    macro avg       1.00      1.00      1.00      8929
# weighted avg       1.00      1.00      1.00      8929

# %%
pred = rf.predict(X_test)
print("The test recall score is {}".format(np.round(recall_score(y_test, pred), 4)))
# Out:
# The test recall score is 0.8103

# %%
sns.heatmap(
    confusion_matrix(y_test, pred),
    annot=True,
    fmt="g",
    cmap="Reds",
    cbar=False,
    annot_kws={"size": 15},
)
plt.title("Confusion matrix (Test set)", fontsize=16)
plt.yticks(rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81      1205
#            1       0.77      0.81      0.79      1028
#
#     accuracy                           0.80      2233
#    macro avg       0.80      0.80      0.80      2233
# weighted avg       0.80      0.80      0.80      2233

# %% [markdown]
# <h3> 8.4) Logistic Regression </h3>

# %%
logreg = LogisticRegression(solver='liblinear')
logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_test)

# %%
print(confusion_matrix(y_pred, y_test))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print('Cross Validation mean:',(cross_val_score(logreg, X_train, y_train, cv=5, n_jobs=2, scoring = 'accuracy').mean()))
# Out:
# [[1008  250]
#  [ 197  778]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      1205
#            1       0.80      0.76      0.78      1028
#
#     accuracy                           0.80      2233
#    macro avg       0.80      0.80      0.80      2233
# weighted avg       0.80      0.80      0.80      2233
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dp/dtjy860d4jz18nc86phz4n7m0000gn/T/ipykernel_55375/1416750934.py in <module>
#       1 print(confusion_matrix(y_pred, y_test))
#       2 print(classification_report(y_test, y_pred))
# ----> 3 print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#       4 print("Precision:",metrics.precision_score(y_test, y_pred))
#       5 print("Recall:",metrics.recall_score(y_test, y_pred))
#
# NameError: name 'metrics' is not defined

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(confusion_matrix(y_pred, y_test), annot=True, fmt="g", cmap="magma")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
